# %%
import bootcampviztools as b
import pandas as pd

# %%
df_titanic = pd.read_csv("./data/titanic.csv")

# %%
df_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
columnas_numericas = df_titanic.describe().columns.to_list()
columnas_numericas
# Out:
# ['survived', 'pclass', 'age', 'sibsp', 'parch', 'fare']

# %%
columnas_categoricas = df_titanic.describe(exclude=["float64","int64"]).columns.to_list()
columnas_categoricas
# Out:
# ['sex',
#  'embarked',
#  'class',
#  'who',
#  'adult_male',
#  'deck',
#  'embark_town',
#  'alive',
#  'alone']

# %% [markdown]
# ### **pinta_distribucion_categoricas**
#
# ```pinta_distribucion_categoricas(df, columnas_categoricas, relativa=False, mostrar_valores=False, giro = 45):```
#
# ```sns.barplot(x=serie.index, y=serie, ax=ax, palette='viridis', hue = serie.index, legend = False)```

# %%
b.pinta_distribucion_categoricas(df_titanic, ['sex', 'embarked']) # Lista de categoricas (para ver de golpe todas), Distribucion valores con --> barplot()

# %% [markdown]
# ### **plot_categorical_relationship_fin**
#
# ```plot_categorical_relationship_fin(df, cat_col1, cat_col2, relative_freq=False, show_values=False, size_group = 5):```
#
# ```sns.barplot(x=cat_col1, y='count', hue=cat_col2, data=data_subset, order=categories_subset)```

# %%
b.plot_categorical_relationship_fin(df_titanic, "sex","class") # Categorica y categorica --> Relacion valores con --> barplot()

# %% [markdown]
# ### **plot_categorical_numerical_relationship**
#
# ```plot_categorical_numerical_relationship(df, categorical_col, numerical_col, show_values=False, measure='mean'):```
#
# ```sns.barplot(x=data_subset.index, y=data_subset.values)```

# %%
b.plot_categorical_numerical_relationship(df_titanic,"sex","fare") # Numerica y categorica --> Relacion valores con (media o mediana) --> barplot()

# %% [markdown]
# ### **plot_combined_graphs**
#
# ```plot_combined_graphs(df, columns, whisker_width=1.5, bins = None):```
#
# ```sns.histplot(df[column], kde=True, ax=axes[i,0] if num_cols > 1 else axes[0], bins= "auto" if not bins else bins)```
#
# ```sns.boxplot(x=df[column], ax=axes[i,1] if num_cols > 1 else axes[1], whis=whisker_width)```

# %%
b.plot_combined_graphs(df_titanic,["age","fare"]) # Numerica o Lista de numericas --> histplot() + boxplot() (se puede modificar el whisker)
# Out:
# (2, 2)

# %% [markdown]
# ### **plot_grouped_boxplots**
#
# ```plot_grouped_boxplots(df, cat_col, num_col):```
#
# ```sns.boxplot(x=cat_col, y=num_col, data=subset_df)```

# %%
b.plot_grouped_boxplots(df_titanic, "sex","age") # Categorica y Numerica --> boxplot()

# %% [markdown]
# ### **plot_grouped_histograms**
#
# ```plot_grouped_histograms(df, cat_col, num_col, group_size):```
#
# ```sns.histplot(subset_df[subset_df[cat_col] == cat][num_col], kde=True, label=str(cat))```

# %%
b.plot_grouped_histograms(df_titanic,"sex","fare", group_size=2) # Categorica y Numerica --> histplot() --> group_size = Segun Categorica

# %% [markdown]
# ### **grafico_dispersion_con_correlacion**
#
# ```grafico_dispersion_con_correlacion(df, columna_x, columna_y, tamano_puntos=50, mostrar_correlacion=False):```
#
# ```sns.scatterplot(data=df, x=columna_x, y=columna_y, s=tamano_puntos)```

# %%
b.grafico_dispersion_con_correlacion(df_titanic,"age","fare") # Numerica y Numerica --> Correlacion entre valores (positiva, negativa, neutral) --> scatterplot()

# %%
df_cities = pd.read_csv("./data/cities.csv")
columnas_numericas = df_cities.describe().columns.to_list()
columnas_numericas
# Out:
# ['Unnamed: 0',
#  'latd',
#  'longd',
#  'elevation_m',
#  'elevation_ft',
#  'population_total',
#  'area_total_sq_mi',
#  'area_land_sq_mi',
#  'area_water_sq_mi',
#  'area_total_km2',
#  'area_land_km2',
#  'area_water_km2',
#  'area_water_percent']

# %% [markdown]
# ### **bubble_plot**
#
# ```bubble_plot(df, col_x, col_y, col_size, scale = 1000):```
#
# ```plt.scatter(df[col_x], df[col_y], s=sizes)```

# %%
b.bubble_plot(df_cities,"latd","longd", col_size="population_total", scale=10000) # Numerica, Numerica y Numerica --> scatter()

# %% [markdown]
# ### **mostrar_diagramas_violin**
#
# ```mostrar_diagramas_violin(df, columnas_numericas):```
#
# ```sns.violinplot(y=df[col])```

# %%
b.mostrar_diagramas_violin(df_titanic,['age',"fare"])  # Lista de numericas --> violinplot()

# %% [markdown]
# ### **plot_multiple_boxplots**
#
# ```plot_multiple_boxplots(df, columns, dim_matriz_visual = 2):```
#
# ```sns.boxplot(data=df, x=column, ax=axes[i])```

# %%
b.plot_multiple_boxplots(df_titanic,['age',"fare"]) # Numerica y Numerica --> boxplot()
